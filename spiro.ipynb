# %%
import math
import numpy as np
x=[]
y=[]
R=6.0
r=1.0
a=8.0

for t in np.arange(0.00,12*math.pi,0.01):
   x.append(((R+r)*math.cos((r/R)*t) - a*math.cos((1+r/R)*t))*0.001-118.2855555555555)
   y.append(((R+r)*math.sin((r/R)*t) - a*math.sin((1+r/R)*t))*0.001+34.0205556)

# %%
for i in range(len(x)):
    print(str(x[i])+","+str(y[i]))
# Out:
# -118.28565555555551,34.0205556
# -118.2856555020839,34.02054743354452
# -118.28565534167649,34.02053926835613
# -118.2856550743555,34.020531105701735
# -118.28565470015798,34.02052294684791
# -118.28565421913572,34.0205147930607
# -118.28565363135542,34.020506645605465
# -118.28565293689846,34.0204985057467
# -118.28565213586107,34.02049037474786
# -118.28565122835423,34.020482253871194
# -118.28565021450365,34.020474144377566
# -118.28564909444978,34.0204660475263
# -118.28564786834781,34.02045796457497
# -118.2856465363676,34.02044989677928
# -118.28564509869368,34.02044184539285
# -118.28564355552524,34.02043381166707
# -118.28564190707607,34.0204257968509
# -118.28564015357456,34.02041780219076
# -118.28563829526365,34.02040982893027
# -118.28563633240084,34.02040187831016
# -118.28563426525805,34.02039395156808
# -118.28563209412171,34.020386049938395
# -118.28562981929265,34.02037817465205
# -118.28562744108608,34.02037032693642
# -118.2856249598315,34.02036250801508
# ...
